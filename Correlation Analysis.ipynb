# %%
#Correlation Analysis for Feature Selection
import pandas as pd
from sklearn.preprocessing import MinMaxScaler

data_path = r'C:\Users\name\OneDrive\Documents\Computer Science Masters\Independent Research Project\Summative Assessment\Artefact Directory\cnp_train_data.xlsx'
df_normal = pd.read_excel(data_path,sheet_name='Train')
X = df_normal.drop(['target'], axis=1)
column_headers = X.columns.values.tolist()

scaler = MinMaxScaler()
scaler.fit(X)
data = scaler.transform(X)
data_df = pd.DataFrame(data, columns = column_headers)

data_df.corr(method = 'spearman')
# Out:
#                                    business_unit_id  received_id  \
# business_unit_id                           1.000000     0.230182
# received_id                                0.230182     1.000000
# received_item_id                           0.230183     0.999997
# packaged_in_quantity                      -0.136040    -0.289890
# supplier_price                            -0.437003    -0.153757
# received_quantity                         -0.123678    -0.294078
# remainder_total                           -0.292992    -0.157102
# tax_percentage                                  NaN          NaN
# gst_tax_incl_cost_amt                           NaN          NaN
# gst_tax_amt                                     NaN          NaN
# gst_supplier_source_cost_incl_tax               NaN          NaN
# gst_ext_cost                                    NaN          NaN
# gst_ext_cost_incl_tax                           NaN          NaN
# expected_tax_percentage                         NaN          NaN
# supplier_id                                0.243621     0.037645
# supplier_item_id                           0.110349     0.006176
# supplier_item_code                        -0.076378     0.018973
# purchase_order_id                         -0.357541    -0.405104
# status_code                               -0.065662    -0.474649
# tax                                       -0.091772    -0.109290
# control_number                            -0.388144    -0.410307
# source_type_code                          -0.358419    -0.406236
# total_cost                                -0.293404    -0.146141
# supplier_cost_source_type_code             0.155229     0.169189
# supplier_total_cost                       -0.355199    -0.395314
#
#                                    received_item_id  packaged_in_quantity  \
# business_unit_id                           0.230183             -0.136040
# received_id                                0.999997             -0.289890
# received_item_id                           1.000000             -0.289812
# packaged_in_quantity                      -0.289812              1.000000
# supplier_price                            -0.153835              0.089387
# received_quantity                         -0.294050              0.968336
# remainder_total                           -0.157091              0.145715
# tax_percentage                                  NaN                   NaN
# gst_tax_incl_cost_amt                           NaN                   NaN
# gst_tax_amt                                     NaN                   NaN
# gst_supplier_source_cost_incl_tax               NaN                   NaN
# gst_ext_cost                                    NaN                   NaN
# gst_ext_cost_incl_tax                           NaN                   NaN
# expected_tax_percentage                         NaN                   NaN
# supplier_id                                0.037649             -0.072697
# supplier_item_id                           0.006449             -0.046595
# supplier_item_code                         0.019405              0.033878
# purchase_order_id                         -0.405084              0.280547
# status_code                               -0.474648              0.460172
# tax                                       -0.109112              0.072945
# control_number                            -0.410304              0.261997
# source_type_code                          -0.406215              0.281255
# total_cost                                -0.146156              0.168103
# supplier_cost_source_type_code             0.169205             -0.067286
# supplier_total_cost                       -0.395306              0.270134
#
#                                    supplier_price  received_quantity  \
# business_unit_id                        -0.437003          -0.123678
# received_id                             -0.153757          -0.294078
# received_item_id                        -0.153835          -0.294050
# packaged_in_quantity                     0.089387           0.968336
# supplier_price                           1.000000           0.066461
# received_quantity                        0.066461           1.000000
# remainder_total                          0.665934           0.171591
# tax_percentage                                NaN                NaN
# gst_tax_incl_cost_amt                         NaN                NaN
# gst_tax_amt                                   NaN                NaN
# gst_supplier_source_cost_incl_tax             NaN                NaN
# gst_ext_cost                                  NaN                NaN
# gst_ext_cost_incl_tax                         NaN                NaN
# expected_tax_percentage                       NaN                NaN
# supplier_id                             -0.050943          -0.032039
# supplier_item_id                         0.291648          -0.040305
# supplier_item_code                       0.245378          -0.018205
# purchase_order_id                        0.201727           0.278405
# status_code                              0.069558           0.467988
# tax                                      0.069571           0.071585
# control_number                           0.232916           0.259191
# source_type_code                         0.200923           0.279070
# total_cost                               0.684687           0.192579
# supplier_cost_source_type_code          -0.064518          -0.065978
# supplier_total_cost                      0.193187           0.270456
#
#                                    remainder_total  tax_percentage  \
# business_unit_id                         -0.292992             NaN
# received_id                              -0.157102             NaN
# received_item_id                         -0.157091             NaN
# packaged_in_quantity                      0.145715             NaN
# supplier_price                            0.665934             NaN
# received_quantity                         0.171591             NaN
# remainder_total                           1.000000             NaN
# tax_percentage                                 NaN             NaN
# gst_tax_incl_cost_amt                          NaN             NaN
# gst_tax_amt                                    NaN             NaN
# gst_supplier_source_cost_incl_tax              NaN             NaN
# gst_ext_cost                                   NaN             NaN
# gst_ext_cost_incl_tax                          NaN             NaN
# expected_tax_percentage                        NaN             NaN
# supplier_id                               0.100197             NaN
# supplier_item_id                          0.374977             NaN
# supplier_item_code                        0.301227             NaN
# purchase_order_id                         0.172823             NaN
# status_code                               0.170981             NaN
# tax                                       0.058871             NaN
# control_number                            0.212088             NaN
# source_type_code                          0.171797             NaN
# total_cost                                0.974415             NaN
# supplier_cost_source_type_code           -0.047186             NaN
# supplier_total_cost                       0.203849             NaN
#
#                                    gst_tax_incl_cost_amt  gst_tax_amt  ...  \
# business_unit_id                                     NaN          NaN  ...
# received_id                                          NaN          NaN  ...
# received_item_id                                     NaN          NaN  ...
# packaged_in_quantity                                 NaN          NaN  ...
# supplier_price                                       NaN          NaN  ...
# received_quantity                                    NaN          NaN  ...
# remainder_total                                      NaN          NaN  ...
# tax_percentage                                       NaN          NaN  ...
# gst_tax_incl_cost_amt                                NaN          NaN  ...
# gst_tax_amt                                          NaN          NaN  ...
# gst_supplier_source_cost_incl_tax                    NaN          NaN  ...
# gst_ext_cost                                         NaN          NaN  ...
# gst_ext_cost_incl_tax                                NaN          NaN  ...
# expected_tax_percentage                              NaN          NaN  ...
# supplier_id                                          NaN          NaN  ...
# supplier_item_id                                     NaN          NaN  ...
# supplier_item_code                                   NaN          NaN  ...
# purchase_order_id                                    NaN          NaN  ...
# status_code                                          NaN          NaN  ...
# tax                                                  NaN          NaN  ...
# control_number                                       NaN          NaN  ...
# source_type_code                                     NaN          NaN  ...
# total_cost                                           NaN          NaN  ...
# supplier_cost_source_type_code                       NaN          NaN  ...
# supplier_total_cost                                  NaN          NaN  ...
#
#                                    supplier_item_id  supplier_item_code  \
# business_unit_id                           0.110349           -0.076378
# received_id                                0.006176            0.018973
# received_item_id                           0.006449            0.019405
# packaged_in_quantity                      -0.046595            0.033878
# supplier_price                             0.291648            0.245378
# received_quantity                         -0.040305           -0.018205
# remainder_total                            0.374977            0.301227
# tax_percentage                                  NaN                 NaN
# gst_tax_incl_cost_amt                           NaN                 NaN
# gst_tax_amt                                     NaN                 NaN
# gst_supplier_source_cost_incl_tax               NaN                 NaN
# gst_ext_cost                                    NaN                 NaN
# gst_ext_cost_incl_tax                           NaN                 NaN
# expected_tax_percentage                         NaN                 NaN
# supplier_id                                0.521743            0.025553
# supplier_item_id                           1.000000            0.386101
# supplier_item_code                         0.386101            1.000000
# purchase_order_id                         -0.076310           -0.044954
# status_code                                0.033950            0.003618
# tax                                       -0.060618            0.008832
# control_number                            -0.083133           -0.065869
# source_type_code                          -0.079077           -0.046781
# total_cost                                 0.378902            0.293781
# supplier_cost_source_type_code             0.084833            0.112038
# supplier_total_cost                       -0.106081           -0.063428
#
#                                    purchase_order_id  status_code       tax  \
# business_unit_id                           -0.357541    -0.065662 -0.091772
# received_id                                -0.405104    -0.474649 -0.109290
# received_item_id                           -0.405084    -0.474648 -0.109112
# packaged_in_quantity                        0.280547     0.460172  0.072945
# supplier_price                              0.201727     0.069558  0.069571
# received_quantity                           0.278405     0.467988  0.071585
# remainder_total                             0.172823     0.170981  0.058871
# tax_percentage                                   NaN          NaN       NaN
# gst_tax_incl_cost_amt                            NaN          NaN       NaN
# gst_tax_amt                                      NaN          NaN       NaN
# gst_supplier_source_cost_incl_tax                NaN          NaN       NaN
# gst_ext_cost                                     NaN          NaN       NaN
# gst_ext_cost_incl_tax                            NaN          NaN       NaN
# expected_tax_percentage                          NaN          NaN       NaN
# supplier_id                                -0.103464     0.048586 -0.060010
# supplier_item_id                           -0.076310     0.033950 -0.060618
# supplier_item_code                         -0.044954     0.003618  0.008832
# purchase_order_id                           1.000000     0.192838  0.203754
# status_code                                 0.192838     1.000000  0.052969
# tax                                         0.203754     0.052969  1.000000
# control_number                              0.672463     0.198279  0.268213
# source_type_code                            0.999258     0.193084  0.203056
# total_cost                                  0.171097     0.171872  0.046410
# supplier_cost_source_type_code             -0.050997    -0.074818 -0.158424
# supplier_total_cost                         0.532096     0.186621  0.222082
#
#                                    control_number  source_type_code  \
# business_unit_id                        -0.388144         -0.358419
# received_id                             -0.410307         -0.406236
# received_item_id                        -0.410304         -0.406215
# packaged_in_quantity                     0.261997          0.281255
# supplier_price                           0.232916          0.200923
# received_quantity                        0.259191          0.279070
# remainder_total                          0.212088          0.171797
# tax_percentage                                NaN               NaN
# gst_tax_incl_cost_amt                         NaN               NaN
# gst_tax_amt                                   NaN               NaN
# gst_supplier_source_cost_incl_tax             NaN               NaN
# gst_ext_cost                                  NaN               NaN
# gst_ext_cost_incl_tax                         NaN               NaN
# expected_tax_percentage                       NaN               NaN
# supplier_id                             -0.066281         -0.100992
# supplier_item_id                        -0.083133         -0.079077
# supplier_item_code                      -0.065869         -0.046781
# purchase_order_id                        0.672463          0.999258
# status_code                              0.198279          0.193084
# tax                                      0.268213          0.203056
# control_number                           1.000000          0.673103
# source_type_code                         0.673103          1.000000
# total_cost                               0.219790          0.169815
# supplier_cost_source_type_code          -0.288069         -0.077570
# supplier_total_cost                      0.802763          0.538887
#
#                                    total_cost  supplier_cost_source_type_code  \
# business_unit_id                    -0.293404                        0.155229
# received_id                         -0.146141                        0.169189
# received_item_id                    -0.146156                        0.169205
# packaged_in_quantity                 0.168103                       -0.067286
# supplier_price                       0.684687                       -0.064518
# received_quantity                    0.192579                       -0.065978
# remainder_total                      0.974415                       -0.047186
# tax_percentage                            NaN                             NaN
# gst_tax_incl_cost_amt                     NaN                             NaN
# gst_tax_amt                               NaN                             NaN
# gst_supplier_source_cost_incl_tax         NaN                             NaN
# gst_ext_cost                              NaN                             NaN
# gst_ext_cost_incl_tax                     NaN                             NaN
# expected_tax_percentage                   NaN                             NaN
# supplier_id                          0.106332                       -0.038832
# supplier_item_id                     0.378902                        0.084833
# supplier_item_code                   0.293781                        0.112038
# purchase_order_id                    0.171097                       -0.050997
# status_code                          0.171872                       -0.074818
# tax                                  0.046410                       -0.158424
# control_number                       0.219790                       -0.288069
# source_type_code                     0.169815                       -0.077570
# total_cost                           1.000000                       -0.047369
# supplier_cost_source_type_code      -0.047369                        1.000000
# supplier_total_cost                  0.211276                       -0.487174
#
#                                    supplier_total_cost
# business_unit_id                             -0.355199
# received_id                                  -0.395314
# received_item_id                             -0.395306
# packaged_in_quantity                          0.270134
# supplier_price                                0.193187
# received_quantity                             0.270456
# remainder_total                               0.203849
# tax_percentage                                     NaN
# gst_tax_incl_cost_amt                              NaN
# gst_tax_amt                                        NaN
# gst_supplier_source_cost_incl_tax                  NaN
# gst_ext_cost                                       NaN
# gst_ext_cost_incl_tax                              NaN
# expected_tax_percentage                            NaN
# supplier_id                                  -0.071959
# supplier_item_id                             -0.106081
# supplier_item_code                           -0.063428
# purchase_order_id                             0.532096
# status_code                                   0.186621
# tax                                           0.222082
# control_number                                0.802763
# source_type_code                              0.538887
# total_cost                                    0.211276
# supplier_cost_source_type_code               -0.487174
# supplier_total_cost                           1.000000
#
# [25 rows x 25 columns]
